# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from tqdm import tqdm
import seaborn as sns
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# %%
review_path = "yelp_Fall2023/review.json"
business_path = "yelp_Fall2023/business.json"
mobility_path = "yelp_Fall2023/Trips_by_Distance.csv"

# %%
business_data = pd.read_json(business_path, lines = True)

# %%
business_data = business_data.dropna()

# %%
bars_business_data = business_data[business_data.categories.str.contains("bar|Bars")]

# %%
bars_business_data.describe()
# Out:
#            latitude     longitude         stars  review_count       is_open
# count  12872.000000  12872.000000  12872.000000  12872.000000  12872.000000
# mean      36.384210    -88.767756      3.715701    129.403745      0.701445
# std        6.054382     13.839064      0.671914    221.384225      0.457642
# min       27.555127   -119.983922      1.000000      5.000000      0.000000
# 25%       29.962553    -90.249359      3.500000     22.000000      0.000000
# 50%       38.627015    -86.146093      4.000000     60.000000      1.000000
# 75%       39.948843    -75.606171      4.000000    150.000000      1.000000
# max       53.646365    -74.682591      5.000000   5721.000000      1.000000

# %%
business_data.describe()
# Out:
#             latitude      longitude          stars   review_count  \
# count  117618.000000  117618.000000  117618.000000  117618.000000
# mean       36.612308     -89.277679       3.659321      52.958238
# std         5.838800      14.804658       0.932171     135.126694
# min        27.555127    -120.095137       1.000000       5.000000
# 25%        32.173332     -90.349720       3.000000       9.000000
# 50%        38.731374     -86.120175       4.000000      18.000000
# 75%        39.953499     -75.449811       4.500000      46.000000
# max        53.651838     -73.200457       5.000000    7568.000000
#
#              is_open
# count  117618.000000
# mean        0.807495
# std         0.394269
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %%
business_data.dtypes
# Out:
# business_id      object
# name             object
# address          object
# city             object
# state            object
# postal_code      object
# latitude        float64
# longitude       float64
# stars           float64
# review_count      int64
# is_open           int64
# attributes       object
# categories       object
# hours            object
# dtype: object

# %%
# Define the criteria for successful business
bars_business_data['successful'] = ((bars_business_data['stars'] >= 3.5) & (bars_business_data['review_count'] >= 100)).astype('int64')

# Prepare the data for logistic regression
X = bars_business_data[['successful']]  # Predictor variable
y = bars_business_data['is_open']       # Response variable

# Add a constant to the model (intercept)
X = sm.add_constant(X)

# Perform logistic regression
model = sm.Logit(y, X)
result = model.fit()

# Print the summary of the regression
print(result.summary())

# Calculating the odds ratio
odds_ratio = pd.DataFrame({'Odds Ratio': result.params.apply(lambda x: np.exp(x))})
print(odds_ratio)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.593301
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                is_open   No. Observations:                12872
# Model:                          Logit   Df Residuals:                    12870
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 03 Dec 2023   Pseudo R-squ.:                 0.02679
# Time:                        16:00:03   Log-Likelihood:                -7637.0
# converged:                       True   LL-Null:                       -7847.2
# Covariance Type:            nonrobust   LLR p-value:                 1.902e-93
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6105      0.022     27.541      0.000       0.567       0.654
# successful     0.9196      0.047     19.509      0.000       0.827       1.012
# ==============================================================================
#             Odds Ratio
# const         1.841401
# successful    2.508294
# /var/folders/dy/d8nzqt0x6dlbq5kqh3ppwvs00000gn/T/ipykernel_15339/3864789580.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bars_business_data['successful'] = ((bars_business_data['stars'] >= 3.5) & (bars_business_data['review_count'] >= 100)).astype('int64')

# %%
# illinois_business_data = 
temp = bars_business_data[bars_business_data.state == 'IL']

# %%
len(bars_business_data[(bars_business_data['stars'] >= 3.5) & (bars_business_data['review_count'] >= 100)])
# Out:
# 3950

# %%
trips_data = pd.read_csv(mobility_path, index_col = None)

# %%
trips_data.tail()
# Out:
#          Level        Date  State FIPS State Postal Code  County FIPS  \
# 5560749  State  2023/10/07        10.0                DE          NaN
# 5560750  State  2023/10/07        23.0                ME          NaN
# 5560751  State  2023/10/07        40.0                OK          NaN
# 5560752  State  2023/10/07        55.0                WI          NaN
# 5560753  State  2023/10/07        54.0                WV          NaN
#
#         County Name  Population Staying at Home  \
# 5560749         NaN                    193623.0
# 5560750         NaN                    265741.0
# 5560751         NaN                    746731.0
# 5560752         NaN                   1107713.0
# 5560753         NaN                    371816.0
#
#          Population Not Staying at Home  Number of Trips  Number of Trips <1  \
# 5560749                        780141.0        4222025.0           1105040.0
# 5560750                       1078471.0        6422140.0           1475329.0
# 5560751                       3210240.0       16949155.0           4344331.0
# 5560752                       4714721.0       28209395.0           7574840.0
# 5560753                       1420331.0        7596814.0           1812012.0
#
#          ...  Number of Trips 5-10  Number of Trips 10-25  \
# 5560749  ...              693535.0               652105.0
# 5560750  ...             1058192.0              1117974.0
# 5560751  ...             2591151.0              2720144.0
# 5560752  ...             4402765.0              4301354.0
# 5560753  ...             1242039.0              1202927.0
#
#          Number of Trips 25-50  Number of Trips 50-100  \
# 5560749               223670.0                 77334.0
# 5560750               404352.0                119612.0
# 5560751               952152.0                433461.0
# 5560752              1513604.0                611522.0
# 5560753               430595.0                159008.0
#
#          Number of Trips 100-250  Number of Trips 250-500  \
# 5560749                  26266.0                   2843.0
# 5560750                  32754.0                   2194.0
# 5560751                 201816.0                  23013.0
# 5560752                 276734.0                  30407.0
# 5560753                  67406.0                   7926.0
#
#          Number of Trips >=500             Row ID  Week Month
# 5560749                 2098.0  10-00000-20231007    40    10
# 5560750                 2987.0  23-00000-20231007    40    10
# 5560751                 7480.0  40-00000-20231007    40    10
# 5560752                16301.0  55-00000-20231007    40    10
# 5560753                 1783.0  54-00000-20231007    40    10
#
# [5 rows x 22 columns]

# %%
trips_data.Level.value_counts()
# Out:
# Level
# County      5470222
# State         88791
# National       1741
# Name: count, dtype: int64

# %%
bars_business_data.is_open.value_counts()
# Out:
# is_open
# 1    9029
# 0    3843
# Name: count, dtype: int64

# %%
state_data = trips_data[trips_data['Level'] == 'State']

# Convert 'Date' to datetime and extract the day of the week
state_data['DayOfWeek'] = pd.to_datetime(state_data['Date']).dt.day_name()

# Calculate average mobility (Number of Trips) for each state and day
average_mobility = state_data.groupby(['State Postal Code', 'DayOfWeek'])['Number of Trips'].mean()

# Identify top 3 days of mobility for each state
top_days = average_mobility.groupby(level=0).nlargest(3).reset_index(level=0, drop=True)

# Sample restaurant hours (assuming this format for each restaurant)
restaurant_hours = {
    'Tuesday': '0:0-0:0',
    'Wednesday': '13:30-22:0',
    'Thursday': '13:30-22:0',
    'Friday': '13:30-23:0',
    'Saturday': '13:30-23:0',
    'Sunday': '13:30-22:0'
}

# Function to check if a restaurant is open on a given day
def is_open_on_day(day, hours):
    if (day in hours):
        if (hours[day] != '0:0-0:0'):
            return True
        else:
            False
    return False

# Check if the restaurant is open on top mobility days
# for state, days in top_days.groupby('State Postal Code'):
#     print(f"State: {state}")
#     for day in days.index.get_level_values(1):
#         open_status = is_open_on_day(day, restaurant_hours)
#         print(f" - {day}: {'Open' if open_status else 'Closed'}")
# Out:
# /var/folders/dy/d8nzqt0x6dlbq5kqh3ppwvs00000gn/T/ipykernel_15339/1127205767.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_data['DayOfWeek'] = pd.to_datetime(state_data['Date']).dt.day_name()

# %%
tdict = {}
for state, days in top_days.groupby('State Postal Code'):
    if state not in tdict:
        tdict[state] = np.array(days.index.get_level_values(1))

# %%
bars_business_data[bars_business_data['state'] != 'AB'].apply(
    lambda x: is_open_on_day(x['hours'], tdict[x['state']]), axis=1
)
bars_opdata = bars_business_data[['business_id', 'state', 'attributes', 'hours']].reset_index(drop = True)

# %%
bars_opdata['Monday'] = bars_opdata.hours.apply(lambda x : is_open_on_day("Monday", x))
bars_opdata['Tuesday'] = bars_opdata.hours.apply(lambda x : is_open_on_day("Tuesday", x))
bars_opdata['Wednesday'] = bars_opdata.hours.apply(lambda x : is_open_on_day("Wednesday", x))
bars_opdata['Thursday'] = bars_opdata.hours.apply(lambda x : is_open_on_day("Thursday", x))
bars_opdata['Friday'] = bars_opdata.hours.apply(lambda x : is_open_on_day("Friday", x))
bars_opdata['Saturday'] = bars_opdata.hours.apply(lambda x : is_open_on_day("Saturday", x))
bars_opdata['Sunday'] = bars_opdata.hours.apply(lambda x : is_open_on_day("Sunday", x))

# %%
del bars_opdata['hours']

# %%
bars_opdata = bars_opdata[bars_opdata['state'] != 'AB']

# %%
df = state_data.groupby(['State Postal Code', 'DayOfWeek'], as_index = False)['Number of Trips'].agg('mean')
max_sales = df.groupby('State Postal Code')['Number of Trips'].max()
min_sales = df.groupby('State Postal Code')['Number of Trips'].min()

# Calculating the difference and percentage difference
difference = max_sales - min_sales
percentage_difference = (difference / max_sales) * 100

# Creating a new DataFrame to display the results
result = pd.DataFrame({
    'Max Number of Trips': max_sales,
    'Min Number of Trips': min_sales,
    'Difference': difference,
    'Percentage Difference': percentage_difference
})

# %%
business_ids = bars_opdata.business_id.unique()
review_data = pd.DataFrame()
for chunk in tqdm(pd.read_json('yelp_Fall2023/review.json', lines = True, chunksize = 100000)):
    temp = chunk[chunk.business_id.isin(business_ids)]
    review_data = pd.concat([review_data, temp])
# Out:
# 70it [03:27,  2.96s/it]

# %%
del review_data['user_id']
del review_data['useful']
del review_data['funny']
del review_data['cool']

# %%
tokenizer = AutoTokenizer.from_pretrained('sshleifer/distilbart-cnn-12-6')
model = AutoModelForSeq2SeqLM.from_pretrained('sshleifer/distilbart-cnn-12-6')
def summarize_text(text):
    inputs = tokenizer([text], max_length=1024, return_tensors='pt', truncation=True)
    summary_ids = model.generate(inputs['input_ids'], num_beams=2, max_length=200, early_stopping=True)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    return summary

# %%
from multiprocessing.dummy import Pool as ThreadPool
long_reviews = review_data[review_data['text'].apply(lambda x: len(x.split(" ")) >= 100)].reset_index(drop=True)
# Function to process the reviews using ThreadPool
def process_reviews(reviews):
    pool = ThreadPool(4)  # Number of threads
    results = pool.map(summarize_text, reviews)
    pool.close()
    pool.join()
    return results

# Call the function and assign the results to the 'summary' column
long_reviews['summary'] = process_reviews(long_reviews['text'])
# Out:
# KeyboardInterrupt

# %%
long_reviews
# Out:
#                      review_id             business_id  stars  \
# 0       KU_O5udG6zpxOg-VcAEodg  XQfwVwDr-v0ZS3_CbbE5Xw      3
# 1       LnGZB0fjfgeVDVz5IHuEVA  rBdG_23USc7DletfZ11xGA      4
# 2       ZVvhc3Go7v5I8XTiVoWmqQ  ut6fi2W2YaipNOqvi7e0jw      3
# 3       lUUhg8ltDsUZ9h0xnwY4Dg  cPepkJeRMtHapc_b2Oe_dw      4
# 4       YcLXh-3UC9y6YFAI9xxzPQ  oBhJuukGRqPVvYBfTkhuZA      4
# ...                        ...                     ...    ...
# 632074  4ncWtKqNnGcpHk2isnWZzg  IoRTm7IAJqBbHpiisUBnLg      5
# 632075  flql0FgydC3n0Hwx6kcJoQ  oHvEgLH6pAkcrPmeR1l3UQ      5
# 632076  ZcEx4UEnTnR_TEPEqwkKjA  Ea663rIHyKXz2VP2DPH7Cg      4
# 632077  pJvL9AN6gDoixiLLNF1c7w  r2IhvKZQ_wLR5mLBnPOilg      4
# 632078  RwcKOdEuLRHNJe4M9-qpqg  VAeEXLbEcI9Emt9KGYq9aA      3
#
#                                                      text                date
# 0       If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 1       The hubby and I have been here on multiple occ... 2014-08-10 19:41:43
# 2       Upland is a brewery based out of Bloomington, ... 2014-11-12 14:12:20
# 3       I was really between 3 and 4 stars for this on... 2018-07-17 03:30:07
# 4       The only reason I didn't give this restaurant ... 2015-03-05 03:37:54
# ...                                                   ...                 ...
# 632074  I have been a regular of Tony's and the previo... 2020-07-30 18:36:12
# 632075  We are huge Retreat fans! One of my favorite t... 2018-04-26 05:15:22
# 632076  I decided to try this place out after Christma... 2020-01-13 04:21:38
# 632077  One of my favorite restaurants in Santa Barbar... 2019-03-27 04:16:27
# 632078  Located in the 'Walking District' in Nashville... 2018-01-02 22:50:47
#
# [632079 rows x 5 columns]

# %%
# tdict

# %%
del bars_opdata['attributes']

# %%
bars_opdata.to_csv("../Documents/STAT628/bars_day_op_data.csv", index = None)

# %%
day = pd.DataFrame(tdict).T
day['state'] = day.index
day.to_csv("../Documents/STAT628/bestdays_data.csv", index = None)

# %%
review_data['date'] = review_data['date'].astype('datetime64[ns]')
review_data['day_of_week'] = review_data['date'].dt.day_name()
review_data['year'] = review_data['date'].dt.year
review_data['hour'] = review_data['date'].dt.hour

# %%
del bars_business_data['latitude']
del bars_business_data['longitude']
del bars_business_data['attributes']
del bars_business_data['hours']
del bars_business_data['successful']

# %%
bars_business_data = bars_business_data[bars_business_data['state'] != 'AB']

# %%
t = bars_business_data.merge(review_data, on = 'business_id', how = 'left')

# %%
# t.to_csv("../Documents/STAT628/usmerged_data.csv.gz", index = None, compression = 'gzip')

# %%
bars_attribute = pd.read_csv("../Documents/STAT628/barsAttr.csv", index_col = None)

# %%
topattrs = ['business_id', 'stars','NoiseLevel', 'hipster', 'HasTV', 'intimate', 'upscale', 'RestaurantsGoodForGroups']

# %%
bars_attribute.columns
# Out:
# Index(['business_id', 'stars', 'garage', 'lot', 'street', 'valet', 'validated',
#        'BusinessAcceptsCreditCards', 'OutdoorSeating',
#        'RestaurantsPriceRange2', 'HasTV', 'casual', 'classy', 'divey',
#        'hipster', 'intimate', 'romantic', 'touristy', 'trendy', 'upscale',
#        'Alcohol', 'RestaurantsGoodForGroups', 'RestaurantsReservations',
#        'RestaurantsTakeOut', 'BikeParking', 'WiFi', 'RestaurantsDelivery',
#        'NoiseLevel', 'name', 'city', 'state', 'is_open'],
#       dtype='object')

# %%
bars_attribute.groupby('hipster').agg({'stars':'mean'})
# Out:
#             stars
# hipster
# 0        3.686334
# 1        4.022073

# %%
bars_attribute.groupby('RestaurantsGoodForGroups').agg({'stars':'mean'})
# Out:
#                              stars
# RestaurantsGoodForGroups
# 0                         3.952977
# 1                         3.619011

# %%
bars_attribute[topattrs].to_csv("../Documents/STAT628/topbar_attrs_data.csv", index = None)

# %%
t.groupby('state', as_index = False).agg({'review_id' : 'nunique'}).sort_values('review_id', ascending = False)
# Out:
#    state  review_id
# 11    PA     384609
# 3     FL     311138
# 7     LA     191236
# 12    TN     187308
# 8     MO     134089
# 6     IN     130151
# 0     AZ      90392
# 1     CA      86093
# 10    NV      83199
# 9     NJ      43578
# 4     ID      35896
# 2     DE      15663
# 5     IL      10790

# %%
t[t.state.isin(['CA'])].to_csv("../Documents/STAT628/camerged_data.csv.gz", index = None, compression = 'gzip')

# %%
t[t.state.isin(['CA'])].to_csv("../Documents/STAT628/camerged_data.csv", index = None)

# %%
t['day_of_review'] = t['date'].astype('datetime64[ns]').dt.day_name()
t['hour_of_review'] = t['date'].astype('datetime64[ns]').dt.hour

# %%
t
# Out:
#                     business_id               name              address  \
# 0        MUTTqe8uqyMdBl186RmNeA           Tuna Bar          205 Race St
# 1        MUTTqe8uqyMdBl186RmNeA           Tuna Bar          205 Race St
# 2        MUTTqe8uqyMdBl186RmNeA           Tuna Bar          205 Race St
# 3        MUTTqe8uqyMdBl186RmNeA           Tuna Bar          205 Race St
# 4        MUTTqe8uqyMdBl186RmNeA           Tuna Bar          205 Race St
# ...                         ...                ...                  ...
# 1704137  cM6V90ExQD6KMSU3rRB5ZA  Dutch Bros Coffee  1181 N Milwaukee St
# 1704138  cM6V90ExQD6KMSU3rRB5ZA  Dutch Bros Coffee  1181 N Milwaukee St
# 1704139  cM6V90ExQD6KMSU3rRB5ZA  Dutch Bros Coffee  1181 N Milwaukee St
# 1704140  cM6V90ExQD6KMSU3rRB5ZA  Dutch Bros Coffee  1181 N Milwaukee St
# 1704141  cM6V90ExQD6KMSU3rRB5ZA  Dutch Bros Coffee  1181 N Milwaukee St
#
#                  city state postal_code  stars_x  review_count  is_open  \
# 0        Philadelphia    PA       19106      4.0           245        1
# 1        Philadelphia    PA       19106      4.0           245        1
# 2        Philadelphia    PA       19106      4.0           245        1
# 3        Philadelphia    PA       19106      4.0           245        1
# 4        Philadelphia    PA       19106      4.0           245        1
# ...               ...   ...         ...      ...           ...      ...
# 1704137         Boise    ID       83704      4.0            33        1
# 1704138         Boise    ID       83704      4.0            33        1
# 1704139         Boise    ID       83704      4.0            33        1
# 1704140         Boise    ID       83704      4.0            33        1
# 1704141         Boise    ID       83704      4.0            33        1
#
#                                                 categories  \
# 0                        Sushi Bars, Restaurants, Japanese
# 1                        Sushi Bars, Restaurants, Japanese
# 2                        Sushi Bars, Restaurants, Japanese
# 3                        Sushi Bars, Restaurants, Japanese
# 4                        Sushi Bars, Restaurants, Japanese
# ...                                                    ...
# 1704137  Cafes, Juice Bars & Smoothies, Coffee & Tea, R...
# 1704138  Cafes, Juice Bars & Smoothies, Coffee & Tea, R...
# 1704139  Cafes, Juice Bars & Smoothies, Coffee & Tea, R...
# 1704140  Cafes, Juice Bars & Smoothies, Coffee & Tea, R...
# 1704141  Cafes, Juice Bars & Smoothies, Coffee & Tea, R...
#
#                       review_id  stars_y  \
# 0        XYaDbPKyJAu4k2aUOIth5g        5
# 1        tpLolBuBTx_Ncx3RSf7WBw        1
# 2        u0mLU6WALXLsCM8sNtGxlw        5
# 3        R5Ha2XF3zevW0D3D6J1d2w        5
# 4        6PywmKFi6ma5GfEykq0suw        5
# ...                         ...      ...
# 1704137  a2vvvqHK29v7IlmgRsufbw        1
# 1704138  E2qgVNEnBo-98acyIXXagQ        5
# 1704139  cbSKIvLa9fKHjtqCs6K9UQ        5
# 1704140  nvJgAjJicW92IdQLGVF3VQ        5
# 1704141  GYFl7Z-nQo2tfu1nBWSQWQ        5
#
#                                                       text  \
# 0        Stopped in to check out this new spot around t...
# 1        I live in the neighborhood and used to order a...
# 2        We came here tonight just for a date night. We...
# 3        Wow! What a great dining adventure! Huge rolls...
# 4        Wonderfully fresh sushi, amazing lobster fried...
# ...                                                    ...
# 1704137  They turned off the heaters while we were wait...
# 1704138  Very friendly and fast service!  We are from o...
# 1704139  I used to be a hardcore Starbucks fan, that sa...
# 1704140  Super friendly service but terrible whiskey. I...
# 1704141  I love this place! I would go here everyday af...
#
#                        date day_of_week  year  hour
# 0       2017-12-16 00:13:06    Saturday  2017     0
# 1       2018-04-28 00:46:05    Saturday  2018     0
# 2       2018-01-10 02:56:31   Wednesday  2018     2
# 3       2017-12-29 23:57:16      Friday  2017    23
# 4       2018-01-22 01:47:25      Monday  2018     1
# ...                     ...         ...   ...   ...
# 1704137 2021-11-25 03:35:25    Thursday  2021     3
# 1704138 2021-05-21 14:20:47      Friday  2021    14
# 1704139 2015-05-20 14:44:19   Wednesday  2015    14
# 1704140 2020-05-17 02:19:36      Sunday  2020     2
# 1704141 2019-07-31 02:50:15   Wednesday  2019     2
#
# [1704142 rows x 17 columns]

# %%
bars_attribute[topattrs]
# Out:
#                   business_id  stars  NoiseLevel  hipster  HasTV  intimate  \
# 0      k0hlBqXX-Bt0vf1op7Jr1w    3.0           1        0      1         0
# 1      MUTTqe8uqyMdBl186RmNeA    4.0           1        0      0         0
# 2      QdN72BWoyFypdGJhhI5r7g    4.0           1        1      1         0
# 3      lk9IwjZXqUMqqOhM774DtQ    3.5           1        0      0         0
# 4      txyXRytGjwOXvS8s4sc-WA    3.0           0        0      0         0
# ...                       ...    ...         ...      ...    ...       ...
# 13643  IeSD0nMKRFYUTnR5nZH1CQ    3.5           1        1      1         0
# 13644  -R9t30RvsG-Rtiq63yuEmg    2.5           1        0      1         0
# 13645  esBGrrmuZzSiECyRBoKvvA    4.5           0        0      1         0
# 13646  w_4xUt-1AyY2ZwKtnjW0Xg    4.5           1        0      1         0
# 13647  cM6V90ExQD6KMSU3rRB5ZA    4.0           1        0      0         0
#
#        upscale  RestaurantsGoodForGroups
# 0            0                         1
# 1            0                         1
# 2            0                         1
# 3            0                         1
# 4            0                         0
# ...        ...                       ...
# 13643        0                         1
# 13644        0                         1
# 13645        0                         1
# 13646        0                         1
# 13647        0                         1
#
# [13648 rows x 8 columns]

# %%
bars_attribute.groupby('RestaurantGoodForGroups').agg({'stars':'mean'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[198], line 1
# ----> 1 bars_attribute.groupby('RestaurantGoodForGroups').agg({'stars':'mean'})
#
# File ~/miniconda3/envs/ptenv/lib/python3.10/site-packages/pandas/core/frame.py:8872, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8869 if level is None and by is None:
#    8870     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8872 return DataFrameGroupBy(
#    8873     obj=self,
#    8874     keys=by,
#    8875     axis=axis,
#    8876     level=level,
#    8877     as_index=as_index,
#    8878     sort=sort,
#    8879     group_keys=group_keys,
#    8880     observed=observed,
#    8881     dropna=dropna,
#    8882 )
#
# File ~/miniconda3/envs/ptenv/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1274, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1271 self.dropna = dropna
#    1273 if grouper is None:
# -> 1274     grouper, exclusions, obj = get_grouper(
#    1275         obj,
#    1276         keys,
#    1277         axis=axis,
#    1278         level=level,
#    1279         sort=sort,
#    1280         observed=False if observed is lib.no_default else observed,
#    1281         dropna=self.dropna,
#    1282     )
#    1284 if observed is lib.no_default:
#    1285     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File ~/miniconda3/envs/ptenv/lib/python3.10/site-packages/pandas/core/groupby/grouper.py:1009, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1007         in_axis, level, gpr = False, gpr, None
#    1008     else:
# -> 1009         raise KeyError(gpr)
#    1010 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1011     # Add key to exclusions
#    1012     exclusions.add(gpr.key)
#
# KeyError: 'RestaurantGoodForGroups'
